# %%
# %env TF_FORCE_UNIFIED_MEMORY=1
# Out:
# env: TF_FORCE_UNIFIED_MEMORY=1

# %%
import unlimtd_f
import time
from jax import random, jit, pmap, value_and_grad, lax
import dataset_multi_infinite
import dataset_lines_infinite
import test
import plots
import ntk
import nll
import jax
from jax import numpy as np
import pickle
import models
import utils

# %%
seed = 1655235988902897757
print(seed)
# Out:
# 1655235988902897757

# %%
def nll(kernel_self, part_apply_fn, x_a, y_a, maddox_noise):
    """
    Computes the NLL of this data (one task only) wrt the kernel
    x_a is a (batch_size, input_dims) array (! has lost n_tasks)
    y_a is a (batch_size, reg_dim) array (! has lost n_tasks)
    """
    cov_a_a = kernel_self(x_a)
    K = cov_a_a.shape[0]
    cov_a_a = cov_a_a + maddox_noise ** 2 * np.eye(K)
    
    # prior mean is 0
    y_a = np.reshape(y_a, (-1))

    L = jax.scipy.linalg.cho_factor(cov_a_a)
    ypred_a = np.reshape(part_apply_fn(inputs = x_a), (-1,))
    alpha = jax.scipy.linalg.cho_solve(L, y_a - ypred_a)
    return 0.5 * (y_a - ypred_a).T @ alpha + np.sum(np.log(np.diag(L[0]))) + 0.5 * K * np.log(2 * np.pi)

# %%
def nll_batch_one_kernel(kernel_self, part_apply_fn, x_a, y_a, maddox_noise, jacobian, mean):
    """
    NLL for a batch of tasks, when there is only one kernel (singGP)
    x_a is (n_tasks, batch_size, input_dims) (input_dims are (128, 128, 1) for vision, (1,) for toy problems)
    y_a is (n_tasks, batch_size, reg_dim)
    """
    def f(carry, task_data):
        x_a, y_a = task_data
        y_a = y_a - utils.falseaffine_correction0(jacobian, mean, x_a)
        loss_here = nll(kernel_self, part_apply_fn, x_a, y_a, maddox_noise)
        return None, loss_here

    _, losses = lax.scan(f, None, (x_a, y_a))

    return np.array(losses)

# %%
from functools import partial

def nll_batch_average_identity_cov(current_params, current_mean, apply_fn, current_batch_stats, x_a, y_a, maddox_noise):
    _, kernel_self, jacobian = get_kernel_and_jac_identity_cov(apply_fn, current_params, current_batch_stats)
    part_apply_fn = (partial(apply_fn, current_params, current_batch_stats))
    
    return np.mean(nll_batch_one_kernel(kernel_self, part_apply_fn, x_a, y_a, maddox_noise, jacobian, current_mean))

# %%
def pmapable_loss_identity_cov(current_state, x_a, y_a, maddox_noise):
    # we can't pass current_state because we have to explicitely show the variable
    loss, (gradients_p, gradients_m) = value_and_grad(nll_batch_average_identity_cov, argnums = (0, 1) )(current_state.params,
                                                              current_state.mean,
                                                              current_state.apply_fn,
                                                              current_state.batch_stats,
                                                              x_a,
                                                              y_a,
                                                              maddox_noise)
    
    return loss, (gradients_p, gradients_m)

# %%
@jit
def batch_stats_updater(current_state, x_a):
    # shape of x_a is (n_tasks, batch_size, inputs_dims...)
    
    batch_stats = current_state.batch_stats
    
    def f(old_batch_stats, _x_a):
        # shape of _x_a is (batch_size, input_dims)
        _, mutated_vars = current_state.apply_fn_raw({"params":current_state.params,
                                                      "batch_stats": old_batch_stats},
                                                     _x_a,
                                                     mutable=["batch_stats"])
        
        new_batch_stats = mutated_vars["batch_stats"]
        return new_batch_stats, None

    batch_stats = dict(batch_stats)
    print(type(batch_stats))
    batch_stats, _ = lax.scan(f, batch_stats, x_a)
    return batch_stats

# %%
@jit
def grad_applier_identity_cov(current_state, gradients_p, gradients_m, new_batch_stats):
    return current_state.apply_gradients(grads_params=gradients_p, grads_mean=gradients_m, new_batch_stats=new_batch_stats)

# %%
def step_identity_cov(key, current_state, n_tasks, K, data_noise, maddox_noise, n_devices, get_train_batch_fn):
    # Draw the samples for this step, and split it to prepare for pmap (jit'd)
    x_a, y_a, x_a_div, y_a_div = get_train_batch_fn(key, n_tasks, K, data_noise, n_devices)
    
    # Compute loss and gradient through gpu parallelization
    unaveraged_losses, (unaveraged_gradients_p, unaveraged_gradients_m) = pmap(pmapable_loss_identity_cov,
                             in_axes=(None, 0, 0, None),
                             static_broadcasted_argnums=(3)
                            )(current_state, x_a_div, y_a_div, maddox_noise)
    
    current_loss = np.mean(unaveraged_losses)
    current_gradients_p = jax.tree_map(lambda array: np.mean(array, axis=0), unaveraged_gradients_p)
    current_gradients_m = jax.tree_map(lambda array: np.mean(array, axis=0), unaveraged_gradients_m)
    
    # Update batch_stats "manually" (jit'd)
    new_batch_stats = batch_stats_updater(current_state, x_a)
    
    # Update state (parameters and optimizer)
    current_state = grad_applier_identity_cov(current_state, current_gradients_p, current_gradients_m, new_batch_stats)
    
    return current_state, current_loss

# %% [markdown]
# ## Unlimitd f training

# %%
from ntk import get_kernel_and_jac_lowdim_cov

def nll_batch_average_lowdim_cov_singGP(current_params, current_mean, current_scale, apply_fn, current_batch_stats, proj, x_a, y_a, maddox_noise):
    _, kernel_self, jacobian = get_kernel_and_jac_lowdim_cov(apply_fn, current_params, current_scale, current_batch_stats, proj)

    part_apply_fn = (partial(apply_fn, current_params, current_batch_stats))
    return np.mean(nll_batch_one_kernel(kernel_self, part_apply_fn, x_a, y_a, maddox_noise, jacobian, current_mean))

# %%
def pmapable_loss_lowdim_cov_singGP(current_state, x_a, y_a, maddox_noise):
    # we can't pass current_state because we have to explicitely show the variable
    loss, (gradients_p, gradients_m, gradients_s) = value_and_grad(nll_batch_average_lowdim_cov_singGP, argnums = (0, 1, 2) )(current_state.params,
                                                              current_state.mean,
                                                              current_state.scale,
                                                              current_state.apply_fn,
                                                              current_state.batch_stats,
                                                              current_state.proj,
                                                              x_a,
                                                              y_a,
                                                              maddox_noise)
    
    return loss, (gradients_p, gradients_m, gradients_s)

# %%
from trainer import grad_applier_lowdim_cov_singGP

def step_lowdim_cov_singGP(key, current_state, n_tasks, K, data_noise, maddox_noise, n_devices, get_train_batch_fn):
    # Draw the samples for this step, and split it to prepare for pmap (jit'd)
    x_a, y_a, x_a_div, y_a_div = get_train_batch_fn(key, n_tasks, K, data_noise, n_devices)
    
    # Compute loss and gradient through gpu parallelization
    unaveraged_losses, (unaveraged_gradients_p, unaveraged_gradients_m, unaveraged_gradients_s) = pmap(pmapable_loss_lowdim_cov_singGP,
                             in_axes=(None, 0, 0, None),
                             static_broadcasted_argnums=(3)
                            )(current_state, x_a_div, y_a_div, maddox_noise)
    
    current_loss = np.mean(unaveraged_losses)
    current_gradients_p = jax.tree_map(lambda array: np.mean(array, axis=0), unaveraged_gradients_p)
    current_gradients_m = jax.tree_map(lambda array: np.mean(array, axis=0), unaveraged_gradients_m)
    current_gradients_s = jax.tree_map(lambda array: np.mean(array, axis=0), unaveraged_gradients_s)
    
    # Update batch_stats "manually" (jit'd)
    new_batch_stats = batch_stats_updater(current_state, x_a)
    
    # Update state (parameters and optimizer)
    current_state = grad_applier_lowdim_cov_singGP(current_state, current_gradients_p, current_gradients_m, current_gradients_s, new_batch_stats)
    
    return current_state, current_loss

# %%
def train_and_eval(key, step, n_epochs, state, n_tasks, K, data_noise, maddox_noise, get_train_batch_fn, eval_during_training_fn):
    """
    Available step functions:
    * step_identity_cov
    * step_lowdim_cov_singGP
    * step_lowdim_cov_mixture

    Available get_train_batch_fn functions:
    * dataset_sines_infinite.get_training_batch
    * dataset_sines_finite.get_training_batch
    * dataset_lines_infinite.get_training_batch
    * dataset_multi_infinite.get_training_batch
    * dataset_shapenet1d.get_training_batch
    
    """
    n_devices = jax.local_device_count()

    print("Starting training with:")
    print(f"-n_epochs={n_epochs}")
    print(f"-n_tasks={n_tasks}")
    print(f"-K={K}")
    print(f"-data_noise={data_noise}")
    print(f"-maddox_noise={maddox_noise}")

    losses = []
    evals = []
    t = time.time_ns()

    for epoch_index in range(n_epochs):
        key, subkey = random.split(key)
        state, current_loss = step(subkey, state, n_tasks, K, data_noise, maddox_noise, n_devices, get_train_batch_fn)

        if(np.isnan(current_loss)):
            print("Nan, aborting")
            break
        
        losses.append(current_loss)

        if epoch_index % 10 == 0:
            print(f"{epoch_index}  | {current_loss:.4f} ({(time.time_ns() - t)/ 10**9:.4f} s)")
        t = time.time_ns()

        if epoch_index % 500 == 0:
            key, subkey = random.split(key)
            current_eval = eval_during_training_fn(subkey, state)
            evals.append( current_eval )
            print(f"Eval: {current_eval}")
    print("Completed training")

    return state, losses, evals

# %%
import trainer
import ntk
import test
import train_states
import models
import utils
import fim

import dataset_sines_infinite
import dataset_sines_finite
import dataset_multi_infinite

from jax import random
from jax import numpy as np
from flax.core import FrozenDict
import optax

from ntk import get_kernel_and_jac_identity_cov
from ntk import get_kernel_and_jac_lowdim_cov

def unlimtd_f_multi_modal_singGP(seed, pre_n_epochs, pre_n_tasks, pre_K, post_n_epochs, post_n_tasks, post_K, data_noise, maddox_noise, meta_lr, subspace_dimension):
    key = random.PRNGKey(seed)
    key_init, key = random.split(key)

    print("===============")
    print("This is UNLIMTD-F")
    print("For the multi-modal dataset: sine + line (both infinite)")
    print("This variant of UNLIMTD-F approaches the distribution with a single GP")
    print("===============")
    print("Creating model")
    model = models.small_network(40, "relu", 1)
    batch = random.uniform(key_init, shape=(5,1), minval=-5, maxval=5)
    init_vars = model.init(key_init, batch)
    apply_fn = utils.apply_fn_wrapper(model.apply, True)
    apply_fn_raw = model.apply

    # Training before finding the FIM matrix
    print("Creating optimizers")
    step = trainer.step_identity_cov
    get_train_batch_fn = dataset_multi_infinite.get_training_batch
    optimizer_params = optax.adam(learning_rate = meta_lr)
    optimizer_mean = optax.adam(learning_rate = meta_lr)
    mean_init = np.zeros( (utils.get_param_size(init_vars["params"]),) )

    pre_state = train_states.TrainStateIdentityCovariance.create(apply_fn=apply_fn, apply_fn_raw=apply_fn_raw, params=init_vars["params"], mean=mean_init, tx_params=optimizer_params, tx_mean=optimizer_mean, batch_stats=FrozenDict())

    def eval_during_pre_training(key, state):
        current_params = state.params
        current_mean = state.mean
        current_batch_stats = state.batch_stats
        kernel, kernel_self, jacobian = ntk.get_kernel_and_jac_identity_cov(apply_fn, current_params, current_batch_stats)

        subkey_1, subkey_2 = random.split(key)
        nlls = test.test_nll_one_kernel(subkey_1, kernel_self, jacobian, dataset_multi_infinite.get_test_batch, K=pre_K, n_tasks=1000, data_noise=data_noise, maddox_noise=maddox_noise, current_mean=current_mean)
        mses = test.test_error_one_kernel(subkey_2, kernel, kernel_self, jacobian, dataset_multi_infinite.get_test_batch, dataset_multi_infinite.error_fn, K=pre_K, L=pre_K, n_tasks=1000, data_noise=data_noise, maddox_noise=maddox_noise, current_mean=current_mean)

        return np.mean(nlls), np.mean(mses)

    print("Starting first part of training (identity covariance)")
    key_pre, key = random.split(key)
    pre_state, pre_losses, pre_evals = train_and_eval(key_pre, step, pre_n_epochs, pre_state, pre_n_tasks, pre_K, data_noise, maddox_noise, get_train_batch_fn, eval_during_pre_training)
    print("Finished first part of training")

    # FIM
    print("Finding projection matrix")
    key_fim, key_data, key = random.split(key, 3)
    # here we use the exact FIM, we do not need to approximate given the (small) size of the network
    # P1 = fim.proj_exact(key=key_fim, apply_fn=apply_fn, current_params=pre_state.params, current_batch_stats=pre_state.batch_stats, subspace_dimension=subspace_dimension)
    P1 = fim.proj_sketch(key=key_fim, apply_fn=apply_fn, current_params=pre_state.params, batch_stats=pre_state.batch_stats, batches=random.uniform(key_data, shape=(100, 1761, 1), minval=-5, maxval=5), subspace_dimension=subspace_dimension)
    print("Found projection matrix")

    # Usual training with projection
    print("Creating optimizers")
    step = step_lowdim_cov_singGP
    optimizer_params = optax.adam(learning_rate = meta_lr)
    optimizer_mean = optax.adam(learning_rate = meta_lr)
    optimizer_scale = optax.adam(learning_rate = meta_lr)
    init_scale = np.ones( (subspace_dimension,) )

    post_state = train_states.TrainStateLowDimCovSingGP.create(apply_fn = apply_fn, apply_fn_raw=apply_fn_raw, params = pre_state.params, mean=pre_state.mean, scale=init_scale, tx_params = optimizer_params, tx_mean = optimizer_mean, tx_scale = optimizer_scale, batch_stats=pre_state.batch_stats, proj = P1)

    def eval_during_post_training(key, state):
        current_params = state.params
        current_batch_stats = state.batch_stats
        current_mean = state.mean
        current_scale = state.scale
        kernel, kernel_self, jacobian = ntk.get_kernel_and_jac_lowdim_cov(apply_fn, current_params, current_scale, current_batch_stats, P1)

        subkey_1, subkey_2 = random.split(key)
        nlls = test.test_nll_one_kernel(subkey_1, kernel_self, jacobian, dataset_multi_infinite.get_test_batch, K=pre_K, n_tasks=1000, data_noise=data_noise, maddox_noise=maddox_noise, current_mean=current_mean)
        mses = test.test_error_one_kernel(subkey_2, kernel, kernel_self, jacobian, dataset_multi_infinite.get_test_batch, dataset_multi_infinite.error_fn, K=pre_K, L=pre_K, n_tasks=1000, data_noise=data_noise, maddox_noise=maddox_noise, current_mean=current_mean)

        return np.mean(nlls), np.mean(mses)

    print("Starting training")
    key_post, key = random.split(key)
    post_state, post_losses, post_evals = train_and_eval(key_post, step, post_n_epochs, post_state, post_n_tasks, post_K, data_noise, maddox_noise, get_train_batch_fn, eval_during_post_training)
    print("Finished training")

    # Returning everything
    return init_vars, pre_state, pre_evals, post_state, pre_losses, post_losses, post_evals

# %%
init_params, pre_state, pre_evals, post_state, pre_losses, post_losses, post_evals = unlimtd_f_multi_modal_singGP(seed=seed,
                                                                                     pre_n_epochs=1000,
                                                                                     pre_n_tasks=24,
                                                                                     pre_K=10,
                                                                                     post_n_epochs=1000,
                                                                                     post_n_tasks=24,
                                                                                     post_K=10,
                                                                                     data_noise=0.05, 
                                                                                     maddox_noise=0.05,
                                                                                     meta_lr=0.001,
                                                                                     subspace_dimension=10)
# Out:
# ===============
# This is UNLIMTD-F
# For the multi-modal dataset: sine + line (both infinite)
# This variant of UNLIMTD-F approaches the distribution with a single GP
# ===============
# Creating model
# Creating optimizers
# Starting first part of training (identity covariance)
# Starting training with:
# -n_epochs=1000
# -n_tasks=24
# -K=10
# -data_noise=0.05
# -maddox_noise=0.05
# 0  | 892.8888 (5.1189 s)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 init_params, pre_state, pre_evals, post_state, pre_losses, post_losses, post_evals = unlimtd_f_multi_modal_singGP(seed=seed,
#       2                                                                                      pre_n_epochs=1000,
#       3                                                                                      pre_n_tasks=24,
#       4                                                                                      pre_K=10,
#       5                                                                                      post_n_epochs=1000,
#       6                                                                                      post_n_tasks=24,
#       7                                                                                      post_K=10,
#       8                                                                                      data_noise=0.05,
#       9                                                                                      maddox_noise=0.05,
#      10                                                                                      meta_lr=0.001,
#      11                                                                                      subspace_dimension=10)
#
# Cell In[15], line 61, in unlimtd_f_multi_modal_singGP(seed, pre_n_epochs, pre_n_tasks, pre_K, post_n_epochs, post_n_tasks, post_K, data_noise, maddox_noise, meta_lr, subspace_dimension)
#      59 print("Starting first part of training (identity covariance)")
#      60 key_pre, key = random.split(key)
# ---> 61 pre_state, pre_losses, pre_evals = train_and_eval(key_pre, step, pre_n_epochs, pre_state, pre_n_tasks, pre_K, data_noise, maddox_noise, get_train_batch_fn, eval_during_pre_training)
#      62 print("Finished first part of training")
#      64 # FIM
#
# Cell In[14], line 45, in train_and_eval(key, step, n_epochs, state, n_tasks, K, data_noise, maddox_noise, get_train_batch_fn, eval_during_training_fn)
#      43 if epoch_index % 500 == 0:
#      44     key, subkey = random.split(key)
# ---> 45     current_eval = eval_during_training_fn(subkey, state)
#      46     evals.append( current_eval )
#      47     print(f"Eval: {current_eval}")
#
# Cell In[15], line 55, in unlimtd_f_multi_modal_singGP.<locals>.eval_during_pre_training(key, state)
#      53 subkey_1, subkey_2 = random.split(key)
#      54 nlls = test.test_nll_one_kernel(subkey_1, kernel_self, jacobian, dataset_multi_infinite.get_test_batch, K=pre_K, n_tasks=1000, data_noise=data_noise, maddox_noise=maddox_noise, current_mean=current_mean)
# ---> 55 mses = test.test_error_one_kernel(subkey_2, kernel, kernel_self, jacobian, dataset_multi_infinite.get_test_batch, dataset_multi_infinite.error_fn, K=pre_K, L=pre_K, n_tasks=1000, data_noise=data_noise, maddox_noise=maddox_noise, current_mean=current_mean)
#      57 return np.mean(nlls), np.mean(mses)
#
# File ~/unlimitd/test.py:28, in test_error_one_kernel(key, kernel, kernel_self, jacobian, get_test_batch_fn, error_fn, K, L, n_tasks, data_noise, maddox_noise, current_mean)
#      25     predictions = predictions + utils.falseaffine_correction0(jacobian, current_mean, _x_b)
#      26     return None, error_fn(predictions, _y_b)
# ---> 28 _, all_errors = lax.scan(f, None, (x_a, y_a, x_b, y_b))
#      30 return all_errors
#
#     [... skipping hidden 1 frame]
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/lax/control_flow/loops.py:281, in scan(f, init, xs, length, reverse, unroll)
#     279   in_flat = [*in_state, *in_carry, *in_ext]
#     280   num_carry += len(attrs_tracked)
# --> 281 out = scan_p.bind(*consts, *in_flat,
#     282                   reverse=reverse, length=length, jaxpr=jaxpr,
#     283                   num_consts=len(consts), num_carry=num_carry,
#     284                   linear=(False,) * (len(consts) + len(in_flat)),
#     285                   unroll=unroll)
#     286 if attrs_tracked:
#     287   out_state, out = split_list(out, [len(attrs_tracked)])
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/lax/control_flow/loops.py:1157, in scan_bind(*args, **params)
#    1155   _scan_typecheck(True, *in_atoms, **params)
#    1156   core.check_jaxpr(params['jaxpr'].jaxpr)
# -> 1157 return core.AxisPrimitive.bind(scan_p, *args, **params)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/core.py:2727, in AxisPrimitive.bind(self, *args, **params)
#    2723 axis_main = max((axis_frame(a).main_trace for a in used_axis_names(self, params)),
#    2724                 default=None, key=lambda t: getattr(t, 'level', -1))
#    2725 top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2726              else axis_main.with_cur_sublevel())
# -> 2727 return self.bind_with_trace(top_trace, args, params)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/core.py:423, in Primitive.bind_with_trace(self, trace, args, params)
#     422 def bind_with_trace(self, trace, args, params):
# --> 423   out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     424   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/core.py:913, in EvalTrace.process_primitive(self, primitive, tracers, params)
#     912 def process_primitive(self, primitive, tracers, params):
# --> 913   return primitive.impl(*tracers, **params)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/dispatch.py:87, in apply_primitive(prim, *args, **params)
#      85 prev = lib.jax_jit.swap_thread_local_state_disable_jit(False)
#      86 try:
# ---> 87   outs = fun(*args)
#      88 finally:
#      89   lib.jax_jit.swap_thread_local_state_disable_jit(prev)
#
#     [... skipping hidden 1 frame]
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/pjit.py:248, in _cpp_pjit.<locals>.cache_miss(*args, **kwargs)
#     246 @api_boundary
#     247 def cache_miss(*args, **kwargs):
# --> 248   outs, out_flat, out_tree, args_flat, jaxpr, attrs_tracked = _python_pjit_helper(
#     249       fun, infer_params_fn, *args, **kwargs)
#     250   executable = _read_most_recent_pjit_call_executable(jaxpr)
#     251   maybe_fastpath_data = _get_fastpath_data(
#     252       executable, out_tree, args_flat, out_flat, attrs_tracked)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/pjit.py:143, in _python_pjit_helper(fun, infer_params_fn, *args, **kwargs)
#     141   args_flat = [*init_states, *args_flat]
#     142 try:
# --> 143   out_flat = pjit_p.bind(*args_flat, **params)
#     144 except pxla.DeviceAssignmentMismatchError as e:
#     145   fails, = e.args
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/core.py:2727, in AxisPrimitive.bind(self, *args, **params)
#    2723 axis_main = max((axis_frame(a).main_trace for a in used_axis_names(self, params)),
#    2724                 default=None, key=lambda t: getattr(t, 'level', -1))
#    2725 top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2726              else axis_main.with_cur_sublevel())
# -> 2727 return self.bind_with_trace(top_trace, args, params)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/core.py:423, in Primitive.bind_with_trace(self, trace, args, params)
#     422 def bind_with_trace(self, trace, args, params):
# --> 423   out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     424   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/core.py:913, in EvalTrace.process_primitive(self, primitive, tracers, params)
#     912 def process_primitive(self, primitive, tracers, params):
# --> 913   return primitive.impl(*tracers, **params)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/pjit.py:1409, in _pjit_call_impl(jaxpr, in_shardings, out_shardings, resource_env, donated_invars, name, keep_unused, inline, *args)
#    1406 has_explicit_sharding = _pjit_explicit_sharding(
#    1407     in_shardings, out_shardings, None, None)
#    1408 if xla_extension_version >= 226:
# -> 1409   return xc._xla.pjit(
#    1410       name, f, call_impl_cache_miss, [], [], donated_argnums,
#    1411       tree_util.dispatch_registry,
#    1412       pxla.shard_arg if xla_extension_version >= 229 else pxla.temp_shard_arg,  # type: ignore
#    1413       _get_cpp_global_cache(has_explicit_sharding))(*args)
#    1414 else:
#    1415   return xc._xla.pjit(name, f, call_impl_cache_miss, [], [], donated_argnums,  # type: ignore
#    1416                       tree_util.dispatch_registry,
#    1417                       _get_cpp_global_cache(has_explicit_sharding))(*args)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/pjit.py:1392, in _pjit_call_impl.<locals>.call_impl_cache_miss(*args_, **kwargs_)
#    1391 def call_impl_cache_miss(*args_, **kwargs_):
# -> 1392   out_flat, compiled = _pjit_call_impl_python(
#    1393       *args, jaxpr=jaxpr, in_shardings=in_shardings,
#    1394       out_shardings=out_shardings, resource_env=resource_env,
#    1395       donated_invars=donated_invars, name=name, keep_unused=keep_unused,
#    1396       inline=inline)
#    1397   fastpath_data = _get_fastpath_data(
#    1398       compiled, tree_structure(out_flat), args, out_flat, [])
#    1399   return out_flat, fastpath_data
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/pjit.py:1325, in _pjit_call_impl_python(jaxpr, in_shardings, out_shardings, resource_env, donated_invars, name, keep_unused, inline, *args)
#    1319 global _most_recent_pjit_call_executable
#    1321 in_shardings = _resolve_in_shardings(
#    1322     args, in_shardings, out_shardings,
#    1323     resource_env.physical_mesh if resource_env is not None else None)
# -> 1325 compiled = _pjit_lower(
#    1326     jaxpr, in_shardings, out_shardings, resource_env,
#    1327     donated_invars, name, keep_unused, inline,
#    1328     lowering_parameters=mlir.LoweringParameters()).compile()
#    1329 _most_recent_pjit_call_executable.weak_key_dict[jaxpr] = compiled
#    1330 # This check is expensive so only do it if enable_checks is on.
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/pjit.py:1463, in _pjit_lower(jaxpr, in_shardings, out_shardings, *args, **kwargs)
#    1461 in_shardings = SameDeviceAssignmentTuple(tuple(in_shardings), da)
#    1462 out_shardings = SameDeviceAssignmentTuple(tuple(out_shardings), da)
# -> 1463 return _pjit_lower_cached(jaxpr, in_shardings, out_shardings, *args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/pjit.py:1511, in _pjit_lower_cached(jaxpr, sdat_in_shardings, sdat_out_shardings, resource_env, donated_invars, name, keep_unused, inline, lowering_parameters, in_layouts, out_layouts)
#    1505   return pxla.lower_mesh_computation(
#    1506     jaxpr, api_name, name, mesh,
#    1507     in_shardings, out_shardings, donated_invars,
#    1508     True, jaxpr.in_avals, tiling_method=None,
#    1509     lowering_parameters=lowering_parameters)
#    1510 else:
# -> 1511   return pxla.lower_sharding_computation(
#    1512       jaxpr, api_name, name, in_shardings, out_shardings,
#    1513       tuple(donated_invars), tuple(jaxpr.in_avals),
#    1514       keep_unused=keep_unused, inline=inline,
#    1515       devices_from_context=(
#    1516           None if mesh is None or mesh.empty else list(mesh.devices.flat)),
#    1517       lowering_parameters=lowering_parameters, in_layouts=in_layouts,
#    1518       out_layouts=out_layouts)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/profiler.py:336, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     333 @wraps(func)
#     334 def wrapper(*args, **kwargs):
#     335   with TraceAnnotation(name, **decorator_kwargs):
# --> 336     return func(*args, **kwargs)
#     337   return wrapper
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/interpreters/pxla.py:2038, in lower_sharding_computation(closed_jaxpr, api_name, fun_name, in_shardings, out_shardings, donated_invars, global_in_avals, keep_unused, inline, devices_from_context, lowering_parameters, in_layouts, out_layouts)
#    2034 semantic_out_shardings = SemanticallyEqualShardings(out_shardings)  # type: ignore
#    2035 prim_requires_devices = dispatch.jaxpr_has_prim_requiring_devices(jaxpr)
#    2037 (module, keepalive, host_callbacks, unordered_effects, ordered_effects,
# -> 2038  nreps, tuple_args, shape_poly_state) = _cached_lowering_to_hlo(
#    2039      closed_jaxpr, api_name, fun_name, backend, semantic_in_shardings,
#    2040      semantic_out_shardings, in_layouts, out_layouts, len(da_object),
#    2041      tuple(da_object) if prim_requires_devices else None, donated_invars,
#    2042      name_stack, all_default_mem_kind, lowering_parameters=lowering_parameters)
#    2044 # backend and device_assignment is passed through to MeshExecutable because
#    2045 # if keep_unused=False and all in_shardings are pruned, then there is no way
#    2046 # to get the device_assignment and backend. So pass it to MeshExecutable
#    2047 # because we calculate the device_assignment and backend before in_shardings,
#    2048 # etc are pruned.
#    2049 return MeshComputation(
#    2050     str(name_stack),
#    2051     module,
#    (...)
#    2072     all_default_mem_kind=all_default_mem_kind,
#    2073     all_args_info=all_args_info)
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/interpreters/pxla.py:1879, in _cached_lowering_to_hlo(closed_jaxpr, api_name, fun_name, backend, semantic_in_shardings, semantic_out_shardings, in_layouts, out_layouts, num_devices, device_assignment, donated_invars, name_stack, all_default_mem_kind, lowering_parameters)
#    1874 ordered_effects = list(effects.ordered_effects.filter_in(closed_jaxpr.effects))
#    1876 with dispatch.log_elapsed_time(
#    1877       "Finished jaxpr to MLIR module conversion {fun_name} in {elapsed_time} sec",
#    1878       fun_name=str(name_stack), event=dispatch.JAXPR_TO_MLIR_MODULE_EVENT):
# -> 1879   lowering_result = mlir.lower_jaxpr_to_module(
#    1880       module_name,
#    1881       closed_jaxpr,
#    1882       ordered_effects=ordered_effects,
#    1883       backend_or_name=backend,
#    1884       # Optionally, override the lowering platform
#    1885       platforms=lowering_parameters.platforms or (backend.platform,),
#    1886       axis_context=axis_ctx,
#    1887       name_stack=name_stack,
#    1888       donated_args=donated_invars,
#    1889       replicated_args=replicated_args,
#    1890       arg_shardings=in_mlir_shardings,
#    1891       result_shardings=out_mlir_shardings,
#    1892       in_layouts=in_layouts,
#    1893       out_layouts=out_layouts,
#    1894       arg_names=jaxpr.debug_info and jaxpr.debug_info.arg_names,
#    1895       result_names=jaxpr.debug_info and jaxpr.debug_info.result_paths,
#    1896       num_replicas=nreps,
#    1897       num_partitions=num_partitions,
#    1898       all_default_mem_kind=all_default_mem_kind,
#    1899       lowering_parameters=lowering_parameters)
#    1900 tuple_args = dispatch.should_tuple_args(len(global_in_avals), backend.platform)
#    1901 unordered_effects = list(
#    1902     effects.ordered_effects.filter_not_in(closed_jaxpr.effects))
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/interpreters/mlir.py:970, in lower_jaxpr_to_module(***failed resolving arguments***)
#     968   attrs["mhlo.num_partitions"] = i32_attr(num_partitions)
#     969   replace_tokens_with_dummy = lowering_parameters.replace_tokens_with_dummy
# --> 970   lower_jaxpr_to_fun(
#     971       ctx, "main", jaxpr, ordered_effects,
#     972       name_stack=name_stack,
#     973       public=True,
#     974       create_tokens=replace_tokens_with_dummy,
#     975       replace_tokens_with_dummy=replace_tokens_with_dummy,
#     976       num_output_tokens=0,
#     977       replicated_args=replicated_args,
#     978       arg_shardings=arg_op_shardings,
#     979       result_shardings=result_op_shardings,
#     980       input_output_aliases=input_output_aliases,
#     981       xla_donated_args=xla_donated_args,
#     982       arg_names=arg_names,
#     983       result_names=result_names,
#     984       arg_memory_kinds=arg_memory_kinds,
#     985       result_memory_kinds=result_memory_kinds,
#     986       arg_layouts=arg_layouts,
#     987       result_layouts=result_layouts)
#     989 try:
#     990   if not ctx.module.operation.verify():
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/interpreters/mlir.py:1415, in lower_jaxpr_to_fun(ctx, name, jaxpr, effects, name_stack, create_tokens, public, replace_tokens_with_dummy, replicated_args, arg_shardings, result_shardings, use_sharding_annotations, input_output_aliases, xla_donated_args, num_output_tokens, api_name, arg_names, result_names, arg_memory_kinds, result_memory_kinds, arg_layouts, result_layouts)
#    1413 callee_name_stack = name_stack.extend(util.wrap_name(name, api_name))
#    1414 consts = [ir_constants(xla.canonicalize_dtype(x)) for x in jaxpr.consts]
# -> 1415 out_vals, tokens_out = jaxpr_subcomp(
#    1416     ctx, jaxpr.jaxpr, callee_name_stack, tokens_in,
#    1417     consts, *args, dim_var_values=dim_var_values)
#    1418 outs = []
#    1419 if create_tokens:
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/interpreters/mlir.py:1596, in jaxpr_subcomp(ctx, jaxpr, name_stack, tokens, consts, dim_var_values, *args)
#    1593   rule_ctx = rule_ctx.replace(axis_size_env=axis_size_env)
#    1595 rule_inputs = map(_unwrap_singleton_ir_values, in_nodes)
# -> 1596 ans = lower_per_platform(rule_ctx, str(eqn.primitive),
#    1597                          platform_rules, default_rule,
#    1598                          eqn.effects,
#    1599                          *rule_inputs, **eqn.params)
#    1601 if effects:
#    1602   # If there were ordered effects in the primitive, there should be output
#    1603   # tokens we need for subsequent ordered effects.
#    1604   tokens_out = rule_ctx.tokens_out
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/interpreters/mlir.py:1704, in lower_per_platform(ctx, description, platform_rules, default_rule, effects, *rule_args, **rule_kwargs)
#    1702 # If there is a single rule left just apply the rule, without conditionals.
#    1703 if len(kept_rules) == 1:
# -> 1704  return kept_rules[0](ctx, *rule_args, **rule_kwargs)
#    1706 assert len(platforms) > 1 and len(kept_rules) >= 2, (platforms, kept_rules)
#    1707 assert len(ctx.dim_var_values) >= 1, "Must have a platform_index variable"
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/interpreters/mlir.py:1791, in lower_fun.<locals>.f_lowered(ctx, *args, **params)
#    1788   jaxpr, _, consts, () = pe.trace_to_jaxpr_dynamic(wrapped_fun, ctx.avals_in)
#    1789   # TODO(frostig,mattjj): check ctx.avals_out against jaxpr avals out?
# -> 1791 out, tokens = jaxpr_subcomp(
#    1792     ctx.module_context, jaxpr, ctx.name_stack, ctx.tokens_in,
#    1793     _ir_consts(consts), *map(wrap_singleton_ir_values, args),
#    1794     dim_var_values=ctx.dim_var_values)
#    1795 ctx.set_tokens_out(tokens)
#    1796 return out
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/interpreters/mlir.py:1596, in jaxpr_subcomp(ctx, jaxpr, name_stack, tokens, consts, dim_var_values, *args)
#    1593   rule_ctx = rule_ctx.replace(axis_size_env=axis_size_env)
#    1595 rule_inputs = map(_unwrap_singleton_ir_values, in_nodes)
# -> 1596 ans = lower_per_platform(rule_ctx, str(eqn.primitive),
#    1597                          platform_rules, default_rule,
#    1598                          eqn.effects,
#    1599                          *rule_inputs, **eqn.params)
#    1601 if effects:
#    1602   # If there were ordered effects in the primitive, there should be output
#    1603   # tokens we need for subsequent ordered effects.
#    1604   tokens_out = rule_ctx.tokens_out
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/interpreters/mlir.py:1704, in lower_per_platform(ctx, description, platform_rules, default_rule, effects, *rule_args, **rule_kwargs)
#    1702 # If there is a single rule left just apply the rule, without conditionals.
#    1703 if len(kept_rules) == 1:
# -> 1704  return kept_rules[0](ctx, *rule_args, **rule_kwargs)
#    1706 assert len(platforms) > 1 and len(kept_rules) >= 2, (platforms, kept_rules)
#    1707 assert len(ctx.dim_var_values) >= 1, "Must have a platform_index variable"
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/lax/control_flow/loops.py:1718, in _while_lowering(ctx, cond_jaxpr, body_jaxpr, cond_nconsts, body_nconsts, *args)
#    1715 body_name_stack = name_stack.extend('body')
#    1716 body_consts = [mlir.ir_constants(xla.canonicalize_dtype(x))
#    1717                for x in body_jaxpr.consts]
# -> 1718 new_z, tokens_out = mlir.jaxpr_subcomp(
#    1719     ctx.module_context, body_jaxpr.jaxpr, body_name_stack,
#    1720     tokens_in, body_consts, *(y + z), dim_var_values=ctx.dim_var_values)
#    1721 out_tokens = [tokens_out.get(eff) for eff in body_effects]
#    1722 if batched:
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/interpreters/mlir.py:1596, in jaxpr_subcomp(ctx, jaxpr, name_stack, tokens, consts, dim_var_values, *args)
#    1593   rule_ctx = rule_ctx.replace(axis_size_env=axis_size_env)
#    1595 rule_inputs = map(_unwrap_singleton_ir_values, in_nodes)
# -> 1596 ans = lower_per_platform(rule_ctx, str(eqn.primitive),
#    1597                          platform_rules, default_rule,
#    1598                          eqn.effects,
#    1599                          *rule_inputs, **eqn.params)
#    1601 if effects:
#    1602   # If there were ordered effects in the primitive, there should be output
#    1603   # tokens we need for subsequent ordered effects.
#    1604   tokens_out = rule_ctx.tokens_out
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/interpreters/mlir.py:1704, in lower_per_platform(ctx, description, platform_rules, default_rule, effects, *rule_args, **rule_kwargs)
#    1702 # If there is a single rule left just apply the rule, without conditionals.
#    1703 if len(kept_rules) == 1:
# -> 1704  return kept_rules[0](ctx, *rule_args, **rule_kwargs)
#    1706 assert len(platforms) > 1 and len(kept_rules) >= 2, (platforms, kept_rules)
#    1707 assert len(ctx.dim_var_values) >= 1, "Must have a platform_index variable"
#
# File ~/.local/lib/python3.10/site-packages/jax/_src/lax/lax.py:2878, in _dot_general_lower(***failed resolving arguments***)
#    2868     rhs = mlir.convert_hlo(ctx, rhs, rhs_aval,
#    2869                            core.ShapedArray(rhs_aval.shape, np.float32))
#    2872 dot_dnums = hlo.DotDimensionNumbers.get(
#    2873     lhs_batching_dimensions=list(lhs_batch),
#    2874     rhs_batching_dimensions=list(rhs_batch),
#    2875     lhs_contracting_dimensions=list(lhs_contracting),
#    2876     rhs_contracting_dimensions=list(rhs_contracting))
#    2877 return [
# -> 2878     hlo.dot_general(
#    2879         mlir.aval_to_ir_type(aval_out),
#    2880         lhs,
#    2881         rhs,
#    2882         dot_dnums,
#    2883         precision_config=precision_attr(precision))
#    2884 ]
#
# File ~/.local/lib/python3.10/site-packages/jaxlib/mlir/dialects/_stablehlo_ops_gen.py:1903, in dot_general(result, lhs, rhs, dot_dimension_numbers, precision_config, loc, ip)
#    1902 def dot_general(result, lhs, rhs, dot_dimension_numbers, *, precision_config=None, loc=None, ip=None) -> _ods_ir.Value:
# -> 1903   return _get_op_result_or_op_results(DotGeneralOp(result=result, lhs=lhs, rhs=rhs, dot_dimension_numbers=dot_dimension_numbers, precision_config=precision_config, loc=loc, ip=ip))
#
# File ~/.local/lib/python3.10/site-packages/jaxlib/mlir/dialects/_stablehlo_ops_gen.py:1854, in DotGeneralOp.__init__(self, result, lhs, rhs, dot_dimension_numbers, precision_config, loc, ip)
#    1852 operands.append(_get_op_result_or_value(lhs))
#    1853 operands.append(_get_op_result_or_value(rhs))
# -> 1854 _ods_context = _ods_get_default_loc_context(loc)
#    1855 attributes["dot_dimension_numbers"] = (dot_dimension_numbers if (
#    1856 isinstance(dot_dimension_numbers, _ods_ir.Attribute) or
#    1857 not _ods_ir.AttrBuilder.contains('StableHLO_DotDimensionNumbers')) else
#    1858   _ods_ir.AttrBuilder.get('StableHLO_DotDimensionNumbers')(dot_dimension_numbers, context=_ods_context))
#    1859 if precision_config is not None: attributes["precision_config"] = (precision_config if (
#    1860     isinstance(precision_config, _ods_ir.Attribute) or
#    1861     not _ods_ir.AttrBuilder.contains('StableHLO_PrecisionConfigAttr')) else
#    1862       _ods_ir.AttrBuilder.get('StableHLO_PrecisionConfigAttr')(precision_config, context=_ods_context))
#
# KeyboardInterrupt:

# %%
output = {}
output["seed"] = seed
output["pre_n_epochs"]=30000
output["pre_n_tasks"]=24
output["pre_K"]=10
output["post_n_epochs"]=30000
output["post_n_tasks"]=24
output["post_K"]=10
output["data_noise"]=0.05
output["maddox_noise"]=0.05
output["meta_lr"]=0.001
output["subspace_dimension"]=10
output["pre_losses"]=pre_losses
output["post_losses"]=post_losses
output["init_params"]=init_params
output["intermediate_params"]=pre_state.params
output["trained_params"]=post_state.params
output["intermediate_mean"]=pre_state.mean
output["trained_mean"]=post_state.mean
output["intermediate_batch_stats"]=pre_state.batch_stats
output["trained_batch_stats"]=post_state.batch_stats
output["trained_scale"]=post_state.scale
output["proj"]=post_state.proj
output["pre_evals"]=pre_evals
output["post_evals"]=post_evals

# %%
with open("logs_final/multi_single_fim_zeroth_order.pickle", "wb") as handle:
    pickle.dump(output, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
with open("logs_final/multi_single_fim_zeroth_order.pickle", "rb") as handle:
    output = pickle.load(handle)

# %%
model = models.small_network(40, "relu", 1)
apply_fn = utils.apply_fn_wrapper(model.apply, False)

# %%
kernel, kernel_self, jac = ntk.get_kernel_and_jac_lowdim_cov(apply_fn, output["trained_params"], output["trained_scale"], output["trained_batch_stats"], output["proj"])

# %%
key = random.PRNGKey(0)

# %%
key, subkey = random.split(key)
plots.plot_notebooks(subkey, kernel, kernel_self, jac, output["trained_mean"], 10, dataset_sines_infinite)

# %%
key, subkey = random.split(key)
plots.plot_notebooks(subkey, kernel, kernel_self, jac, output["trained_mean"], 10, dataset_lines_infinite)
